# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=pd.read_csv('/Users/user/Documents/datasets_19_420_Iris.csv')

# %%
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
data.drop('Id', axis=1, inplace=True)

# %%
data
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
data["Species"].value_counts()
# Out:
# Iris-virginica     50
# Iris-setosa        50
# Iris-versicolor    50
# Name: Species, dtype: int64

# %%
sns.FacetGrid(data, hue="Species") \
   .map(plt.scatter, "SepalLengthCm", "SepalWidthCm") \
   .add_legend()

# %%
s=np.asarray([1,0,0])
ve=np.asarray([0,1,0])
vi=np.asarray([0,0,1])
data['Species'] = data['Species'].map({'Iris-setosa': s, 'Iris-versicolor': ve,'Iris-virginica':vi})

# %%
data
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm    Species
# 0              5.1           3.5            1.4           0.2  [1, 0, 0]
# 1              4.9           3.0            1.4           0.2  [1, 0, 0]
# 2              4.7           3.2            1.3           0.2  [1, 0, 0]
# 3              4.6           3.1            1.5           0.2  [1, 0, 0]
# 4              5.0           3.6            1.4           0.2  [1, 0, 0]
# ..             ...           ...            ...           ...        ...
# 145            6.7           3.0            5.2           2.3  [0, 0, 1]
# 146            6.3           2.5            5.0           1.9  [0, 0, 1]
# 147            6.5           3.0            5.2           2.0  [0, 0, 1]
# 148            6.2           3.4            5.4           2.3  [0, 0, 1]
# 149            5.9           3.0            5.1           1.8  [0, 0, 1]
#
# [150 rows x 5 columns]

# %%
data=data.iloc[np.random.permutation(len(data))]

# %%
data
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm    Species
# 120            6.9           3.2            5.7           2.3  [0, 0, 1]
# 91             6.1           3.0            4.6           1.4  [0, 1, 0]
# 69             5.6           2.5            3.9           1.1  [0, 1, 0]
# 44             5.1           3.8            1.9           0.4  [1, 0, 0]
# 95             5.7           3.0            4.2           1.2  [0, 1, 0]
# ..             ...           ...            ...           ...        ...
# 2              4.7           3.2            1.3           0.2  [1, 0, 0]
# 144            6.7           3.3            5.7           2.5  [0, 0, 1]
# 0              5.1           3.5            1.4           0.2  [1, 0, 0]
# 29             4.7           3.2            1.6           0.2  [1, 0, 0]
# 148            6.2           3.4            5.4           2.3  [0, 0, 1]
#
# [150 rows x 5 columns]

# %%
data=data.iloc[np.random.permutation(len(data))]

# %%
data=data.reset_index(drop=True)

# %%
data
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm    Species
# 0              6.0           2.7            5.1           1.6  [0, 1, 0]
# 1              5.0           2.3            3.3           1.0  [0, 1, 0]
# 2              6.9           3.2            5.7           2.3  [0, 0, 1]
# 3              4.7           3.2            1.3           0.2  [1, 0, 0]
# 4              5.1           2.5            3.0           1.1  [0, 1, 0]
# ..             ...           ...            ...           ...        ...
# 145            4.9           3.1            1.5           0.1  [1, 0, 0]
# 146            6.4           2.9            4.3           1.3  [0, 1, 0]
# 147            5.2           3.4            1.4           0.2  [1, 0, 0]
# 148            4.5           2.3            1.3           0.3  [1, 0, 0]
# 149            6.9           3.1            5.4           2.1  [0, 0, 1]
#
# [150 rows x 5 columns]

# %%
#training data
x_input=data.ix[0:105,['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']]
temp=data['Species']
y_input=temp[0:106]
#test data
x_test=data.ix[106:149,['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']]
y_test=temp[106:150]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-a9f16d50303f> in <module>
#       1 #training data
# ----> 2 x_input=data.ix[0:105,['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']]
#       3 temp=data['Species']
#       4 y_input=temp[0:106]
#       5 #test data
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'ix'
